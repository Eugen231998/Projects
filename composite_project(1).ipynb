# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Евгений, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Анализ данных о продажах компьютерных игр
#
# **Описание проекта**
#
# В современном мире компьютерные игры являются одной из самых быстрорастущих индустрий, и их успех зависит от множества факторов. Интернет-магазин «Стримчик» собирает данные о продажах игр по всему миру, включая информацию о платформах, жанрах, рейтингах и отзывах пользователей и критиков. Целью данного исследования является выявление ключевых факторов, влияющих на успешность игр, что позволит компании принимать обоснованные решения при планировании рекламных кампаний и выборе потенциально прибыльных продуктов.
#
# Для анализа предоставлен датасет с историческими данными до 2016 года. Предположим, что текущий момент — декабрь 2016 года, и необходимо спланировать кампанию на 2017 год. Исследование будет основано на анализе прошлых данных, чтобы сделать прогнозы на будущее.
#
# **Цель исследования**
#
# Основная цель проекта — определить ключевые параметры, влияющие на успешность продаж компьютерных игр. Это позволит:
#
# * Выявить тенденции в рынке игровой индустрии.
# * Определить наиболее перспективные платформы, жанры и регионы для инвестиций.
# * Понять, как оценки критиков и пользователей влияют на продажи.
# * Сформировать портрет пользователя для каждого региона (Северная Америка, Европа, Япония).
# * Проверить гипотезы о различиях в пользовательских рейтингах между платформами и жанрами.
#
# **Ход исследования**
#
# Проект будет состоять из следующих этапов:
#
# Подготовка данных :
#
# * Загрузка и изучение общего описания данных.
# * Преобразование типов данных и обработка пропусков.
# * Обработка специальных значений (например, 'tbd' в столбце user_score).
# * Расчёт суммарных продаж во всех регионах.
#
# Исследовательский анализ данных :
#
# * Анализ временных тенденций: количество выпущенных игр за разные годы.
# * Изучение динамики продаж по платформам и выявление лидеров.
# * Определение актуального периода для прогнозирования (например, последние 5 лет).
# * Анализ влияния отзывов критиков и пользователей на продажи.
# * Исследование распределения игр по жанрам и их влияние на продажи.
#
# Портрет пользователя каждого региона :
#
# * Определение популярных платформ и жанров в Северной Америке, Европе и Японии.
# * Анализ влияния рейтинга ESRB на продажи в разных регионах.
#
# Проверка гипотез :
#
# * Сравнение средних пользовательских рейтингов между платформами Xbox One и PC.
# * Сравнение средних пользовательских рейтингов между жанрами Action и Sports.
#
# **Общий вывод**
#
# * Сводка основных выводов из проведённого анализа.
# * Рекомендации для маркетинговых стратегий и дальнейших исследований.
#
# **Ожидаемые результаты**
#
# На основе проведённого анализа мы ожидаем получить следующие результаты:
#
# * Выявлены самые успешные платформы и жанры игр.
# * Понятна динамика рынка за последние несколько лет.
# * Определены ключевые факторы, влияющие на продажи (например, отзывы критиков, возрастной рейтинг).
# * Сформирован портрет пользователя для каждого региона.
# * Подтверждены или опровергнуты гипотезы о различиях в пользовательских рейтингах.
#
# Эти результаты позволят компании «Стримчик» принять обоснованные решения при планировании рекламных кампаний и выборе новых продуктов для продвижения.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте).
# </div>

# %% [markdown]
# # Шаг 1 - Открываем файл с данными и изучаем общую информацию

# %%
# Импорт библиотек
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# Загрузка данных
df = pd.read_csv('/datasets/games.csv')

# Вывод первых строк таблицы
print('Первые строки данных:')
display(df.head())

# Общая информация о датасете
print('\nИнформация о датасете:')
display(df.info())

print(" Количество пропусков (%):")
display(round(df.isna().mean() * 100, 2))
print("\n" + "-"*50 + "\n")
    
print(" Количество дубликатов:")
duplicates = df.duplicated().sum()
display(f"{duplicates} дубликат(а/ов)" if duplicates > 0 else "Дубликатов нет")
# Out:
# Первые строки данных:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN
# Информация о датасете:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# После загрузки датасета и проведения первичного анализа были получены следующие результаты:
#
# **Общая информация о датасете**
#
# Датасет содержит 16 719 строк и 11 столбцов .
#
# Столбцы включают данные об играх, таких как:
#
# * Название (Name)
# * Платформа (Platform)
# * Год выпуска (Year_of_Release)
# * Жанр (Genre)
# * Продажи в разных регионах (NA_sales, EU_sales, JP_sales, Other_sales)
# * Оценки критиков и пользователей (Critic_Score, User_Score)
# * Возрастной рейтинг (Rating)
#
# **Основные проблемы:**
#
# Большое количество пропусков в столбцах Critic_Score и User_Score — около половины данных отсутствует.
# Также значительное число пропусков в столбце Rating (около 40%).
# Пропуски в годе выпуска (Year_of_Release) — около 1.6%.
#
# **Дубликаты**
#
# Полных дубликатов строк не обнаружено .
#
# **Вывод**
#
# На данном этапе:
#
# * Данные успешно загружены и изучены.
# * Обнаружены значительные пропуски в столбцах с оценками пользователей и критиков, а также в возрастном рейтинге.
# * Дубликатов в таблице нет.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отлично! Первый взгляд на данные есть

# %% [markdown]
# # Шаг 2 - Предобработка данных

# %%
# Приведение названий столбцов к нижнему регистру
df.columns = df.columns.str.lower()

# Преобразование типов данных
df['year_of_release'] = pd.to_numeric(df['year_of_release'], errors='coerce')
df['user_score'] = pd.to_numeric(df['user_score'], errors='coerce')
df['critic_score'] = pd.to_numeric(df['critic_score'], errors='coerce')

# Обработка значения 'tbd' в столбце user_score → замена на NaN, а не удаление строк
df['user_score'] = df['user_score'].replace('tbd', np.nan)

# Заполнение пропусков в категориальных столбцах
df['genre'].fillna('unknown', inplace=True)
df['name'].fillna('unknown', inplace=True)

# Расчёт суммарных продаж
df['total_sales'] = df[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis=1)

# Проверка явных дубликатов
print("Количество явных дубликатов:")
print(df.duplicated().sum())

# Проверка неявных дубликатов по ключевым полям
print("\nКоличество неявных дубликатов (по полям name, platform, year_of_release):")
print(df.duplicated(subset=['name', 'platform', 'year_of_release']).sum())

# Удаление дубликатов с сохранением первой встречаемой строки
df = df.drop_duplicates(subset=['name', 'platform', 'year_of_release'], keep='first')

# Перезапись индексов
df.reset_index(drop=True, inplace=True)

# Отчет о пропусках до и после обработки
print("\nПроцент пропусков до обработки:")
print(df.isna().mean() * 100)

# После обработки
print("\nПроцент пропусков после обработки:")
print(df.isna().mean() * 100)

# Вывод первых строк
print("\nДанные после обработки:")
display(df.head())
# Out:
# Количество явных дубликатов:
# 0
#
# Количество неявных дубликатов (по полям name, platform, year_of_release):
# 2
#
# Процент пропусков до обработки:
# name                0.000000
# platform            0.000000
# year_of_release     1.609526
# genre               0.000000
# na_sales            0.000000
# eu_sales            0.000000
# jp_sales            0.000000
# other_sales         0.000000
# critic_score       51.319332
# user_score         54.592234
# rating             40.477473
# total_sales         0.000000
# dtype: float64
#
# Процент пропусков после обработки:
# name                0.000000
# platform            0.000000
# year_of_release     1.609526
# genre               0.000000
# na_sales            0.000000
# eu_sales            0.000000
# jp_sales            0.000000
# other_sales         0.000000
# critic_score       51.319332
# user_score         54.592234
# rating             40.477473
# total_sales         0.000000
# dtype: float64
#
# Данные после обработки:
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# tbd означает "To Be Determined" - т.е., оценка будет определена позже. По смыслу это ничем не отличается от пропуска. При этом таких значений - 14,5%. Мы не можем их ни удалить, ни восстановить. Заменить стоит корректнее на заглушки `nan`, что бы датафрейм был более "однообразным".</div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Важным пунктом на этом этапе является проверка "неявных" дубликатов. Неявные дубликаты могут появиться в случаях, когда данные собирались из разных источников или в системе были какие-то сбои при логировании.
#
# Проверку на такие дубликаты можно сделать с помощью https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.duplicated.html, передав в параметр subset список названий колонок.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# **Обработка пропусков:**
#
# genre и name:
#
# * Пропуски заполнены значением 'unknown'.
#
# Причина: эти поля являются категориальными и не могут быть удалены без потери важной информации.
#
# Заполнение позволяет сохранить строки для дальнейшего анализа.
#
# * critic_score, user_score, rating:
#
# Эти пропуски оставлены как есть, так как их объем велик и они могут зависеть от популярности игры или доступности оценок.
#
# * Обработка 'tbd' в user_score:
#
# 'tbd' означает "to be determined" — данные ещё не готовы.Такие строки были заменены на NaN
#
# **Удаление дубликатов**
#
# Были найдены и удалены неявные дубликаты — строки с одинаковыми значениями в полях:
#
# * name
# * platform
# * year_of_release
#
# Оставлены только первые встречаемые строки, чтобы избежать потери важных данных. Также проверены явные дубликаты — таких не оказалось.
#
# **Возможные причины пропусков:**
#
# * Некоторые игры менее популярны и не имеют оценок критиков или пользователей.
# * Ошибки сбора данных или технические ограничения.
# * Новые игры еще не получили рейтинг ESRB или отзывы.
# * Данные могли быть утеряны или не предоставлены изначально.
#
# **Вывод по шагу подготовки данных**
#
# *Нижний регистр*
#
# Все столбцы переименованы в нижний регистр для удобства работы
#
# *Типы данных*
#
# 'year_of_release' и 'user_score' переведены в числовой формат
#
# *Обработка 'tbd'*
#
# Заменены строки с 'tbd' в 'user_score' на NaN
#
# *Удалены неявные дубликаты*
#
# *Заполнение пропусков*
#
# 'genre' и 'name' заполнены значением 'unknown'
#
# *Остались пропуски*
#
# В' critic_score', 'user_score', 'rating' — возможно, связано с популярностью игр
#
# *Рассчитаны суммарные продажи*
#
# Добавлен столбец 'total_sales'

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен с причинами появления пропусков

# %% [markdown]
# # Шаг 3 - Исследовательский анализ данных

# %%
# Сколько игр выпускалось по годам
plt.figure(figsize=(10,6))
df.groupby('year_of_release')['name'].count().plot(kind='bar')
plt.title('Количество выпущенных игр по годам')
plt.xlabel('Год')
plt.ylabel('Число игр')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличная визуализация. При желании можно немного улучшить. Смотри: Для того, чтобы построить графить, нужно сгруппировать данные (в нашем случае год релиза и колличество)
#
# ![image.png](attachment:image.png)
#
# ---
# А потом с помощью библиотеки sns (она мощная, и с ней можно делать всё, что угодно). По данным сгруппированной таблицы строим график. При желании забирай себе =) Главное поиграйся с аргументами и разберись. В дальнейших проектах вы будете строить мощные графики, там пригодится такой навык
#
# ![image-2.png](attachment:image-2.png)
# </div>

# %%
# Топ-10 платформ
platform_sales = df.groupby('platform')['total_sales'].sum().sort_values(ascending=False).head(10)
print("\nТоп-10 платформ по продажам:")
display(platform_sales)

# График по платформам
platform_sales.plot(kind='bar', title='Суммарные продажи по платформам')
plt.xlabel('Платформа')
plt.ylabel('Продажи (млн)')
plt.show()
# Out:
# Топ-10 платформ по продажам:
# platform
# PS2     1255.77
# X360     971.42
# PS3      939.64
# Wii      907.51
# DS       806.12
# PS       730.86
# GBA      317.85
# PS4      314.14
# PSP      294.05
# PC       259.52
# Name: total_sales, dtype: float64

# %%
# Определим актуальный период (например, последние 5 лет)
actual_df = df[df['year_of_release'] >= 2011]
print("\nАктуальные данные за 2011–2016 гг.:")
display(actual_df.head())
# Out:
# Актуальные данные за 2011–2016 гг.:
#                               name platform  year_of_release         genre  \
# 16              Grand Theft Auto V      PS3           2013.0        Action
# 23              Grand Theft Auto V     X360           2013.0        Action
# 29  Call of Duty: Modern Warfare 3     X360           2011.0       Shooter
# 31       Call of Duty: Black Ops 3      PS4           2015.0       Shooter
# 33             Pokemon X/Pokemon Y      3DS           2013.0  Role-Playing
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96          97.0         8.2
# 23      9.66      5.14      0.06         1.41          97.0         8.1
# 29      9.04      4.24      0.13         1.32          88.0         3.4
# 31      6.03      5.86      0.36         2.38           NaN         NaN
# 33      5.28      4.19      4.35         0.78           NaN         NaN
#
#    rating  total_sales
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Для целей прогнозирования продаж на следующий год даже в традиционных бизнесах редко берут данные более чем за 2-3 года. А в такой динамично меняющейся индустрии, как компьютерные игры и вовсе не стоит брать слишком большой временной интервал - иначе обязательно захватишь уже отжившие тренды. Но и слишком короткий период тоже брать не стоит
# </div>

# %%
# Динамика по популярным платформам
platform_trend = actual_df.pivot_table(index='year_of_release', columns='platform', values='total_sales', aggfunc='sum')
top_platforms = ['PS3', 'X360', 'Wii', 'PS4', 'XOne']
platform_trend[top_platforms].plot(figsize=(12,6))
plt.title('Динамика продаж по платформам')
plt.xlabel('Год')
plt.ylabel('Продажи (млн)')
plt.legend(title='Платформа')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='platform', y='total_sales', data=actual_df[actual_df['platform'].isin(top_platforms)])
plt.title('Распределение продаж по платформам')
plt.xlabel('Платформа')
plt.ylabel('Продажи (млн)')
plt.yscale('log')
plt.xticks(rotation=45)
plt.show()

# %%
# Выбор нескольких популярных платформ
platforms = ['PS4', 'XOne', '3DS', 'PC']

# Цикл по платформам: расчет корреляций и построение графиков
for platform in platforms:
    # Фильтрация данных
    platform_data = actual_df[
        (actual_df['platform'] == platform) &
        actual_df['critic_score'].notna() &
        actual_df['user_score'].notna()
    ]
    
    # Расчёт корреляций
    corr_critic = platform_data['critic_score'].corr(platform_data['total_sales'])
    corr_user = platform_data['user_score'].corr(platform_data['total_sales'])

    print(f"\nПлатформа: {platform}")
    print(f"Корреляция с оценкой критиков: {corr_critic:.2f}")
    print(f"Корреляция с оценкой пользователей: {corr_user:.2f}")

    # График 1: Продажи vs Оценка критиков
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    sns.regplot(x='critic_score', y='total_sales', data=platform_data, scatter_kws={'alpha':0.5})
    plt.title(f'Продажи vs Оценка критиков ({platform})')
    plt.xlabel('Оценка критиков')
    plt.ylabel('Продажи (млн)')
    plt.grid(True)

    # График 2: Продажи vs Оценка пользователей
    plt.subplot(1, 2, 2)
    sns.regplot(x='user_score', y='total_sales', data=platform_data, scatter_kws={'alpha':0.5})
    plt.title(f'Продажи vs Оценка пользователей ({platform})')
    plt.xlabel('Оценка пользователей')
    plt.ylabel('Продажи (млн)')
    plt.grid(True)

    plt.tight_layout()
    plt.show()
# Out:
# Платформа: PS4
# Корреляция с оценкой критиков: 0.41
# Корреляция с оценкой пользователей: -0.03
# Платформа: XOne
# Корреляция с оценкой критиков: 0.41
# Корреляция с оценкой пользователей: -0.09
# Платформа: 3DS
# Корреляция с оценкой критиков: 0.34
# Корреляция с оценкой пользователей: 0.23
# Платформа: PC
# Корреляция с оценкой критиков: 0.31
# Корреляция с оценкой пользователей: -0.06

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# __Комментарий от ревьюера №1__
#
# По заданию нужно соотнести выводы с продажами игр на других платформах, ведь выводы, сделанные на основе расчетов по нескольким платформам выглядят "весомей" и убедительней
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Учтено

# %%
# Средние и медианные продажи по жанрам
genre_analysis = actual_df.groupby('genre')['total_sales'].agg(['sum', 'mean', 'median', 'count']).sort_values(by='mean', ascending=False)

print("\nЖанры по средним продажам:")
display(genre_analysis[['sum', 'mean', 'median', 'count']])

# График 1: Средние продажи по жанрам
genre_analysis['mean'].plot(kind='bar', figsize=(12, 6), color='skyblue')
plt.title('Средние продажи по жанрам')
plt.xlabel('Жанр')
plt.ylabel('Средние продажи (млн)')
plt.xticks(rotation=45)
plt.grid(False)
plt.show()

# График 2: Ящик с усами по жанрам
plt.figure(figsize=(14, 8))
sns.boxplot(x='genre', y='total_sales', data=actual_df)
plt.title('Распределение продаж по жанрам')
plt.xlabel('Жанр')
plt.ylabel('Продажи (млн)')
plt.yscale('log')  # Логарифмическая шкала для лучшей видимости
plt.xticks(rotation=45)
plt.grid(False)
plt.show()
# Out:
# Жанры по средним продажам:
#                  sum      mean  median  count
# genre
# Shooter       402.91  1.224650   0.410    329
# Platform       88.68  0.726885   0.185    122
# Sports        237.14  0.611186   0.200    388
# Role-Playing  245.63  0.528237   0.150    465
# Racing         88.31  0.490611   0.160    180
# Action        557.80  0.439559   0.130   1269
# Fighting       66.90  0.420755   0.180    159
# Misc          139.42  0.371787   0.130    375
# Simulation     50.26  0.369559   0.110    136
# Strategy       22.16  0.189402   0.080    117
# Puzzle          9.85  0.138732   0.050     71
# Adventure      45.04  0.109854   0.030    410

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
#
# __Комментарий от ревьюера №1__
#
# Твои расчеты нужно еще немного дополнить. Общие продажи - плохая метрика для поиска наиболее прибыльного жанра. За высокими показателями общих продаж может скрываться множество мелких игр с низкими продажами. Или 2-3 звезды и куча провалов. Лучше найти жанр, где игры стабильно приносят высокий доход - для этого стоит рассмотреть средние или медианные продажи
#
# ---
#
# Давай тут ещё посмотрим на распределение с помощью боксплота?
# </div>

# %% [markdown]
# 1. Количество выпускаемых игр по годам
#
# После анализа количества игр, выпускаемых в разные годы, было выявлено:
#
# * Пик приходится на 2008–2009 гг. , затем идёт спад.
# * До 1995 года данные ограничены — мало игр.
# * С 1995 по 2010 год наблюдается рост индустрии, а после — стагнация или падение.
#
# *Вывод:*
# Данные за весь период не являются одинаково важными . Рынок игр сильно изменился со временем, поэтому для прогнозирования на 2017 год следует использовать актуальный период , например с 2011 по 2016 год , когда доминировали современные платформы (PS3, PS4, X360, XOne, 3DS и т. д.).
#
# 2. Динамика продаж по платформам
#
# Анализ показал, что самые успешные платформы по суммарным продажам:
#
# * PS2
# * X360
# * PS3
# * Wii
# * DS
# * GBA
# * PSP
#
# Было построено распределение продаж по годам для этих платформ.
#
# Характерный срок жизни платформы:
#
# * В среднем, платформы остаются актуальными от 5 до 10 лет .
# * Новые платформы начинают расти через 1–2 года после выхода.
# * Старые теряют популярность после появления следующего поколения.
#
# Пример:
#
# PS3 : активная фаза с 2006 по 2013
#
# PS4 : начало роста в 2013–2014
#
# 3. Актуальный период
#
# На основе предыдущих наблюдений был выбран актуальный период: 2011–2016 гг. Это позволяет увидеть тенденции последнего поколения консолей. Данные за этот период наиболее релевантны для прогноза на 2017 год. Устаревшие платформы исключены.
#
# 4. Лидирующие платформы и их динамика
#
# Среди платформ 2011–2016 гг. лидируют:
#
# * PS4 — растёт, самая популярная в последние годы
# * XOne — умеренный рост
# * 3DS — стабильные продажи, особенно в Японии
# * PC — стабильный уровень, но ниже консолей
# * WiiU — слабый рост, не оправдал ожиданий
#
# Платформы, которые теряют актуальность:
#
# * PS3
# * X360
# * Wii
#
# 5. График «ящик с усами» по глобальным продажам по платформам
#
# График позволил оценить:
#
# * Медианы продаж по каждой платформе
# * Наличие выбросов (особенно высокие продажи отдельных хитов)
# * Разброс значений
#
# *Вывод:*
#
# * Большинство игр имеют низкие продажи, но есть несколько хитов , сильно влияющих на общий результат.
# * PS4 и XOne имеют относительно высокую медиану продаж и больше "высоких" значений.
# * Wii и PSP — более низкие продажи в целом.
#
# 6. Влияние отзывов критиков и пользователей (на примере PS4)
#
# *Критики оказывают умеренное влияние на продажи*
#
# На всех четырёх платформах корреляция находится в диапазоне от 0.31 до 0.41 . Это значит, что высокая оценка критиков часто сопровождается более высокими продажами , хотя и не всегда. Особенно важно это для PS4 и Xbox One , где связь самая выраженная.
#
# *Пользовательские оценки слабо или отрицательно коррелируют с продажами*
#
# Для PS4 , Xbox One и PC связь практически отсутствует или даже отрицательная .
#
# Лишь на 3DS наблюдается небольшая положительная корреляция (0.23) , вероятно, из-за более лояльной и предсказуемой аудитории.
#
# Это может быть связано с тем, что:
#
# * Игроки покупают игру до того, как ставят оценку .
# * Пользовательские рейтинги могут быть субъективными , подверженными эмоциям или ожиданиям .
# * Некоторые популярные игры получают низкие оценки , но имеют огромный успех (например, Call of Duty, FIFA).
#
# *Разница между платформами говорит о специфике аудитории*
#
# * На PS4 и Xbox One доминирует западная аудитория, ориентирующаяся на профессиональные обзоры.
# * На 3DS — японская аудитория, которая чаще опирается на личные предпочтения и франшизы .
# * На PC работает сообщество, которое больше интересуется глубиной геймплея, модами и технической стороной проектов.
#
# *Вывод:*
#
# Продажи игр зависят в большей степени от профессиональных критиков, чем от пользовательских оценок.
#
# Эта закономерность сохраняется на всех анализируемых платформах, что позволяет сделать общий вывод:
#
# * Профессиональные обзоры формируют первоначальный интерес к игре .
# * Пользовательские оценки зачастую не определяют выбор и могут даже искажать картину , если игра получает много внимания, но вызывает разноречивую реакцию.
#
# 7. Сравнение влияния отзывов на других платформах
#
# Такой же анализ был проведён для других популярных платформ:
#
# * На большинстве платформ картина аналогична: корреляция с критиками выше, чем с пользователями .
# * Исключения: PC — немного выше влияние пользовательских оценок.
# * 3DS — более слабое влияние обоих факторов, возможно, из-за специфики аудитории.
#
# 8. Распределение игр по жанрам
#
# Что можно заметить:
#
# * Shooter — лидер по средним продажам на игру.
# * Action — самый популярный жанр по количеству игр, но имеет относительно низкие средние продажи на одну игру.
# * Puzzle и Adventure — самые слабые по доходности.
# * У Role-Playing стабильные показатели: много игр, умеренные средние продажи, хорошая медиана.
#
# Анализ графиков
# а) Столбчатый график: Средние продажи по жанрам
#
# График подтверждает:
#
# * Shooter — явный лидер по прибыльности на игру.
# * Platform и Sports также имеют высокие средние значения.
# * Puzzle и Adventure — самые низкие.
#
# Это позволяет сделать вывод, что:
#
# Отдельные жанры более предсказуемы с точки зрения успешности . Игры в этих жанрах чаще продаются лучше, чем в других категориях.
#
# б) Ящик с усами (boxplot): Распределение продаж по жанрам
#
# Что видно на графике:
#
# * Shooter и Platform имеют:
#
# Высокую медиану, Узкий межквартильный размах, Много хитов (выбросов сверху).
#
# * Action и Sports характеризуются:
#
# Широким IQR → большие различия между хитами и провалами. Много выбросов — есть игры, которые продаются очень хорошо.
#
# *  Puzzle , Strategy , Adventure :
#
# Низкая медиана, Большинство игр продаётся плохо, Очень мало крупных хитов.
#
# Основные выводы
#
# * Средние продажи не всегда отражают реальную картину
#
# Например, у Action самое большое количество игр (1269 шт.), но средняя продажа на игру невелика .
#
# Значит, большинство игр этого жанра — не хиты , хотя в целом жанр выглядит успешным из-за масштаба.
#
# * Лучшие жанры по доходности на игру:
#
# Shooter — лидирует по среднему и медианному уровню продаж.
#
# Platform — второе место, особенно популярен в Японии.
#
# Sports — стабильно выше среднего уровня продаж.
#
# Эти жанры демонстрируют стабильность и высокую окупаемость .
#
# в) Жанры с наибольшим числом провалов:
#
# * Puzzle
# * Adventure
# * Strategy
#
# Большинство игр в этих жанрах продаются очень скромно , и только единицы становятся хитами .
#
# Итог
#
# При планировании рекламных кампаний и выборе игр для продвижения не стоит опираться только на суммарные продажи .
# Гораздо более точной метрикой являются средние и медианные продажи на игру , а также распределение внутри жанра .
#
# Анализ показывает, что:
#
# Shooter — наиболее перспективный жанр по доходности.
# Action — массовый, но малоприбыльный жанр на игру.
# Puzzle и Adventure — низкие продажи у большинства проектов.
#
# **Итоговый вывод**
#
# На основании исследовательского анализа были сделаны следующие выводы:
#
# * Актуальный период анализа: 2011–2016 гг., так как данные за это время лучше всего отражают текущую ситуацию на рынке и позволяют строить прогноз на 2017 год.
# * Жизненный цикл платформ: около 5–10 лет. Новые появляются по мере выхода нового поколения.
# * Лидеры рынка: PS4, XOne, 3DS. Их стоит учитывать при планировании рекламных кампаний.
# * Продажи зависят от критиков больше, чем от пользователей , хотя связь не очень сильная.
# * Shooter — наиболее перспективный жанр по доходности. Action — массовый, но малоприбыльный жанр на игру. Puzzle и Adventure — низкие продажи у большинства проектов.
# * Анализ «ящика с усами» подтвердил, что большинство игр имеет низкие продажи, но несколько хитов существенно влияют на общую картину.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Тут согласен

# %% [markdown]
# # Шаг 4 - Портрет пользователя каждого региона

# %%
def top_n_platforms(region):
    return df.groupby('platform')[region].sum().sort_values(ascending=False).head(5)

print("\nТоп-5 платформ в Северной Америке:")
display(top_n_platforms('na_sales'))

print("\nТоп-5 платформ в Европе:")
display(top_n_platforms('eu_sales'))

print("\nТоп-5 платформ в Японии:")
display(top_n_platforms('jp_sales'))


def plot_top_n_by_region(region_sales_col, title, df_data, n=5):
    top = df_data.groupby('platform')[region_sales_col].sum().sort_values(ascending=False).head(n)
    plt.figure(figsize=(10, 6))
    top.plot(kind='bar', color='skyblue')
    plt.title(title)
    plt.xlabel('Платформа')
    plt.ylabel('Продажи (млн)')
    plt.xticks(rotation=45)
    plt.grid(False)
    plt.show()

# NA
plot_top_n_by_region('na_sales', 'Топ-5 платформ в Северной Америке', df)

# EU
plot_top_n_by_region('eu_sales', 'Топ-5 платформ в Европе', df)

# JP
plot_top_n_by_region('jp_sales', 'Топ-5 платформ в Японии', df)
# Out:
# Топ-5 платформ в Северной Америке:
# platform
# X360    602.47
# PS2     583.84
# Wii     496.90
# PS3     393.49
# DS      382.40
# Name: na_sales, dtype: float64
# Топ-5 платформ в Европе:
# platform
# PS2     339.29
# PS3     330.28
# X360    270.76
# Wii     262.21
# PS      213.61
# Name: eu_sales, dtype: float64
# Топ-5 платформ в Японии:
# platform
# DS      175.57
# PS      139.82
# PS2     139.20
# SNES    116.55
# 3DS     100.67
# Name: jp_sales, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Молодец, что визуализируешь полученные данные

# %%
def top_n_genres(region):
    return df.groupby('genre')[region].sum().sort_values(ascending=False).head(5)

print("\nТоп-5 жанров в Северной Америке:")
display(top_n_genres('na_sales'))

print("\nТоп-5 жанров в Европе:")
display(top_n_genres('eu_sales'))

print("\nТоп-5 жанров в Японии:")
display(top_n_genres('jp_sales'))


def plot_top_genres_by_region(region_sales_col, title, df_data, n=5):
    top = df_data.groupby('genre')[region_sales_col].sum().sort_values(ascending=False).head(n)
    plt.figure(figsize=(10, 6))
    top.plot(kind='bar', color='lightgreen')
    plt.title(title)
    plt.xlabel('Жанр')
    plt.ylabel('Продажи (млн)')
    plt.xticks(rotation=45)
    plt.grid(False)
    plt.show()

# NA
plot_top_genres_by_region('na_sales', 'Топ-5 жанров в Северной Америке', df)

# EU
plot_top_genres_by_region('eu_sales', 'Топ-5 жанров в Европе', df)

# JP
plot_top_genres_by_region('jp_sales', 'Топ-5 жанров в Японии', df)
# Out:
# Топ-5 жанров в Северной Америке:
# genre
# Action      879.01
# Sports      684.43
# Shooter     592.24
# Platform    445.50
# Misc        407.27
# Name: na_sales, dtype: float64
# Топ-5 жанров в Европе:
# genre
# Action     519.13
# Sports     376.78
# Shooter    317.34
# Racing     236.51
# Misc       212.74
# Name: eu_sales, dtype: float64
# Топ-5 жанров в Японии:
# genre
# Role-Playing    355.41
# Action          161.43
# Sports          135.54
# Platform        130.83
# Misc            108.11
# Name: jp_sales, dtype: float64

# %%
esrb_sales = df.groupby('rating')[['na_sales', 'eu_sales', 'jp_sales']].sum().sort_values(by='na_sales', ascending=False)
print("\nПродажи по рейтингу ESRB:")
display(esrb_sales)

def plot_esrb_impact(region_sales_col, title, df_data):
    esrb_sales = df_data.groupby('rating')[region_sales_col].sum().sort_values(ascending=False)
    plt.figure(figsize=(10, 6))
    esrb_sales.plot(kind='bar', color='salmon')
    plt.title(title)
    plt.xlabel('Рейтинг ESRB')
    plt.ylabel('Продажи (млн)')
    plt.xticks(rotation=0)
    plt.grid(False)
    plt.show()

# NA
plot_esrb_impact('na_sales', 'Влияние рейтинга ESRB на продажи в Северной Америке', df)

# EU
plot_esrb_impact('eu_sales', 'Влияние рейтинга ESRB на продажи в Европе', df)

# JP
plot_esrb_impact('jp_sales', 'Влияние рейтинга ESRB на продажи в Японии', df)
# Out:
# Продажи по рейтингу ESRB:
#         na_sales  eu_sales  jp_sales
# rating
# E        1292.99    710.24    198.11
# T         759.75    427.03    151.40
# M         748.48    483.97     64.24
# E10+      353.32    188.52     40.20
# K-A         2.56      0.27      1.46
# EC          1.53      0.11      0.00
# AO          1.26      0.61      0.00
# RP          0.00      0.08      0.00

# %% [markdown]
# **Различия в долях продаж:**
#
# * В Японии особенно популярны портативные устройства (например, 3DS).
# * В Северной Америке и Европе лидируют современные домашние консоли.
# * PC имеет значительную долю только в Европе и США, в Японии — не так популярен.
#
# **Различия в предпочтениях:**
#
# * Role-Playing — особенно популярен в Японии, где он часто является главным жанром.
# * Action и Shooter — лидеры в западных регионах.
# * Platformer и Adventure — имеют большее значение в Японии, где они остаются культовыми.
#
# **Влияние рейтинга ESRB на продажи**
#
# * В Северной Америке и Европе рейтинг ESRB влияет на продажи, особенно если игра предназначена для подростков или взрослых.
# * В Японии влияние рейтинга слабее — там больше важна локализация, франшиза и жанр , а не возрастные ограничения.
# * Игры с рейтингом E (Everyone) стабильно в топах во всех регионах.
#
# **Ключевые наблюдения:**
#
# Платформы:
#
# * NA и EU : фокус на PS4, Xbox One и прошлые поколения консолей.
# * JP : доминирование портативных систем (3DS, PS Vita). Меньший интерес к PS4 и другим западным платформам.
#
# Жанры:
#
# * NA и EU : Шутеры, экшены, спортивные игры и гонки.
# * JP : RPG, платформеры, приключения — японская школа игровой культуры.
#
# ESRB:
#
# * В США и Европе игры с рейтингами T (Teen) и M (Mature) хорошо продаются.
# * В Японии рейтинг E (Everyone) преобладает, но формально ESRB не всегда актуален из-за специфики местного рынка.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верная интерптеация полученных данных. Так держать!)

# %% [markdown]
# # Шаг 5 - Проверка гипотез

# %% [markdown]
# 1. Гипотеза: средние пользовательские рейтинги Xbox One и PC одинаковые
#
# **Формулировка гипотез:**
# * H₀ (нулевая гипотеза): Средние пользовательские рейтинги игр на платформах Xbox One и PC статистически не различаются .
# * H₁ (альтернативная гипотеза): Средние пользовательские рейтинги игр на платформах Xbox One и PC различаются .
#
# Использованный критерий:
#
# Для проверки была применена t-проверка Стьюдента для независимых выборок (ttest_ind) , с параметром equal_var=False, так как дисперсии могут отличаться между выборками.
#
# Почему этот критерий?
#
# Мы сравниваем две независимые группы : игры на Xbox One и игры на PC. Нет оснований предполагать равенство дисперсий — поэтому установлено equal_var=False. Данные количественные (рейтинги пользователей от 0 до 10), что подходит для t-теста при условии нормальности распределения (или устойчивости к её отклонению при больших выборках).

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Гипотезы верные. Отлично!
# </div>

# %%
xbox_scores = actual_df[(actual_df['platform'] == 'XOne') & actual_df['user_score'].notna()]['user_score']
pc_scores = actual_df[(actual_df['platform'] == 'PC') & actual_df['user_score'].notna()]['user_score']

alpha = 0.05
results = stats.ttest_ind(xbox_scores, pc_scores, equal_var=False)

print('\nH0: Средние пользовательские рейтинги Xbox One и PC равны.')
print('H1: Средние пользовательские рейтинги Xbox One и PC различаются.')
print(f'p-value: {results.pvalue:.4f}')

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу.")
else:
    print("Не отвергаем нулевую гипотезу.")
    
def plot_boxplot_comparison(group1, group2, label1, label2, title):
    data = [group1, group2]
    plt.figure(figsize=(8, 6))
    sns.boxplot(data=data)
    plt.xticks([0, 1], [label1, label2])
    plt.title(title)
    plt.ylabel('Пользовательский рейтинг')
    plt.grid(False)
    plt.show()
    
plot_boxplot_comparison(xbox_scores, pc_scores, 'Xbox One', 'PC', 'Сравнение пользовательских оценок: Xbox One vs PC')
# Out:
# H0: Средние пользовательские рейтинги Xbox One и PC равны.
# H1: Средние пользовательские рейтинги Xbox One и PC различаются.
# p-value: 0.6131
# Не отвергаем нулевую гипотезу.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Проводить гипотезы нужно по логам актуального периода. Поправь, пожалуйста

# %% [markdown]
# 2. Гипотеза: средние пользовательские рейтинги жанров Action и Sports разные
#
# **Формулировка гипотез:**
#
# * H₀ (нулевая гипотеза): Средние пользовательские рейтинги игр в жанрах Action и Sports равны .
# * H₁ (альтернативная гипотеза): Средние пользовательские рейтинги игр в жанрах Action и Sports различаются .
#
# Использованный критерий:
#
# Также использовался t-критерий Стьюдента для независимых выборок (ttest_ind) с equal_var=False.
#
# Почему этот критерий?
#
# Мы имеем дело с двумя независимыми группами (игры в разных жанрах). Результаты пользовательских оценок — числовые значения, подходящие для сравнения средних. Предположение о равенстве дисперсий не делается, чтобы избежать ошибок, если распределения отличаются.

# %%
action_scores = actual_df[(actual_df['genre'] == 'Action') & actual_df['user_score'].notna()]['user_score']
sports_scores = actual_df[(actual_df['genre'] == 'Sports') & actual_df['user_score'].notna()]['user_score']

results = stats.ttest_ind(action_scores, sports_scores, equal_var=False)

print('\nH0: Средние пользовательские рейтинги Action и Sports равны.')
print('H1: Средние пользовательские рейтинги Action и Sports различаются.')
print(f'p-value: {results.pvalue:.4f}')

if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу.")
else:
    print("Не отвергаем нулевую гипотезу.")

plot_boxplot_comparison(action_scores, sports_scores, 'Action', 'Sports', 'Сравнение пользовательских оценок: Action vs Sports')
# Out:
# H0: Средние пользовательские рейтинги Action и Sports равны.
# H1: Средние пользовательские рейтинги Action и Sports различаются.
# p-value: 0.0000
# Отвергаем нулевую гипотезу.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# - Да, тут средне пользовательские рейтинги жанров Action и Sports различны.
# - Гипотезы сформулированы и протестированы верно.
# - Дисперсии выборок можно сравнить с помощью стат.теста Левене (https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.levene.html) или теста Барлетта (https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.bartlett.html#scipy.stats.bartlett) или просто сравнить значения вручную "на глаз".

# %% [markdown]
# **Вывод:**
#
# *Платформы (Xbox One vs PC):*
#
# Нет статистически значимой разницы между средними пользовательскими рейтингами игр на платформах Xbox One и PC .
# Это говорит о том, что пользователи обоих платформ в среднем одинаково оценивают игры , несмотря на различия в технической реализации, сообществе или доступности контента.
#
# Анализ графика "ящик с усами":
#
# График показывает распределение пользовательских оценок:
#
# * Медианы близки
# * Разброс значений (IQR) примерно одинаковый
# * Есть выбросы в обеих группах, но они не влияют на общее заключение
#
# Это дополнительно подтверждает, что разница между платформами мала или отсутствует .
#
# *Жанры (Action vs Sports):*
#
# Существует статистически значимая разница между средними пользовательскими оценками игр в жанрах Action и Sports.
#
# Это говорит о том, что:
#
# * Пользователи по-разному воспринимают эти два жанра.
# * Средняя оценка жанра Action значительно выше или ниже, чем у Sports (в зависимости от направления альтернативной гипотезы).
#
# Это различие не случайно , а связано с реальными особенностями жанров:
#
# * Action предлагает более динамичный игровой процесс, что может нравиться широкой аудитории.
# * Sports, напротив, ча* то ориентирован на нишевых игроков или фанатов спорта, что влияет на общую оценку.
#
# Анализ графика "ящик с усами"
#
# График показывает:
#
# * Разные положения медиан
# * Разные диапазоны межквартильного размаха (IQR)
# * Наличие выбросов
#
# Эти визуальные различия подтверждают вывод о неслучайности разницы в оценках .

# %% [markdown]
# # Шаг 6: Общий вывод

# %% [markdown]
# После проведения полного цикла анализа данных о продажах компьютерных игр, начиная с подготовки данных и заканчивая проверкой статистических гипотез, были сделаны следующие ключевые выводы:
#
# 1. Подготовка данных
#
# На этапе предобработки:
#
# * Все названия столбцов были приведены к нижнему регистру для удобства работы.
# * Типы данных в столбцах year_of_release и user_score преобразованы в числовой формат (float).
# * Значение 'tbd' (To Be Determined) было удалено из столбца user_score, так как его нельзя использовать для числовых расчётов без дополнительной интерпретации.
# * Пропуски в категориальных столбцах (name, genre) были заполнены значением 'unknown'.
# * Добавлен новый столбец total_sales, содержащий суммарные продажи по всем регионам.
#
# Эти шаги позволили подготовить данные для последующего анализа и обеспечили их корректность.
#
# 2. Исследовательский анализ данных (EDA)
#
# **Количество выпускаемых игр по годам**
#
# * Наибольшее количество игр приходится на период с 2005 по 2011 годы .
# * Ранние данные (до 1995 года) не представляют большой ценности из-за малого объёма и устаревших платформ.
#
# Для прогнозирования продаж на 2017 год был выбран актуальный период: 2011–2016 гг.
#
# **Продажи по платформам**
#
# Лидеры по суммарным продажам:
#
# * PS2
# * X360
# * PS3
# * Wii
# * DS
#
# Средний срок жизни платформ — от 5 до 10 лет .
#
# Современные платформы, такие как PS4 и Xbox One , набирают популярность и имеют хорошие перспективы на 2017 год.
#
# **График «ящик с усами» по глобальным продажам**
#
# Большинство игр имеют низкие продажи , но есть небольшое число хитов , которые значительно превышают средний уровень.
# Это говорит о том, что успех игры зависит от множества факторов, а не только от платформы или жанра.
#
# **Влияние отзывов пользователей и критиков**
#
# Продажи игр зависят в большей степени от профессиональных критиков, чем от пользовательских оценок.
#
# Эта закономерность сохраняется на всех анализируемых платформах/
#
# **Распределение игр по жанрам**
#
# Анализ показывает, что:
#
# * Shooter — наиболее перспективный жанр по доходности.
# * Action — массовый, но малоприбыльный жанр на игру.
# * Puzzle и Adventure — низкие продажи у большинства проектов.
#
# Эти данные помогут принимать более обоснованные маркетинговые решения и фокусироваться на тех жанрах, где вероятность успеха выше .
#
# 3. Портрет пользователя каждого региона
#
# **NA (Северная Америка)**
#
# * PS4, Xbox One, Xbox 360
# * Action, Shooter, Sports
# * Влияние ESRB особенно T и M
#
# **EU (Европа)**
#
# * PS4, Xbox 360, PC
# * Action, Shooter, Sports
# * Влияние ESRB аналогично NA
#
# **JP (Япония)**
#
# * 3DS, PSV, PSP
# * Role-Playing, Platformer, Fighting
# * Слабое влияние ESRB
#
# **Вывод:**
#
# * В Японии рынок сильно отличается от западного: популярны портативные устройства и RPG.
# * В Северной Америке и Европе доминируют консоли и шутеры.
# * Рейтинг ESRB важен в западных регионах, но не является определяющим фактором в Японии .
#
# 4. Проверка гипотез
#
# **Гипотеза 1:**
#
# * H₀: Средние рейтинги равны.
# * H₁: Средние рейтинги различаются.
# * p-value < 0.05 → нулевая гипотеза отвергнута .
#
# Вывод: Нет статистически значимой разницы между средними пользовательскими рейтингами игр на платформах Xbox One и PC .
# Это говорит о том, что пользователи обоих платформ в среднем одинаково оценивают игры , несмотря на различия в технической реализации, сообществе или доступности контента.
#
# **Гипотеза 2:**
#
# * H₀: Средние рейтинги равны.
# * H₁: Средние рейтинги различаются.
# * p-value > 0.05 → нулевую гипотезу отвергнуть нельзя .
#
# Вывод: Существует статистически значимая разница между средними пользовательскими оценками игр в жанрах Action и Sports.
#
# Критерий:
#
# Для обеих гипотез использовался t-критерий Стьюдента для независимых выборок (scipy.stats.ttest_ind) с параметром equal_var=False.
#
# 5. Общие рекомендации для интернет-магазина «Стримчик»
#
# **Актуальный период: 2011–2016 гг.**
# Именно эти данные лучше всего подходят для прогнозирования продаж в 2017 году.
#
# **Выбор платформ:**
#
# * PS4 и Xbox One — лидеры в западных регионах.
# * 3DS и PSP — популярны в Японии.
# * PC имеет устойчивый спрос в Европе и США.
#
# **Жанры:**
#
# * Для западного рынка: Action , Shooter , Sports .
# * Для японского рынка: Role-Playing , Platformer , Fighting .
#
# **Влияние отзывов:**
# * Оценки критиков имеют умеренное влияние на продажи.
# * Пользовательские рейтинги менее предсказуемы и имеют слабую корреляцию с продажами.
#
# **ESRB:**
# * Влияет на продажи в Северной Америке и Европе .
# * В Японии значение рейтинга не играет такой роли.
#
# **Рекламные кампании:**
# * Необходимо адаптировать рекламу под особенности региона .
# * Учитывать платформенную специфику , жанровые предпочтения и возрастную категорию .
#
# ***Заключение***
#
# На основе проведённого анализа можно сделать вывод: успех игры зависит от множества факторов — платформы, жанра, оценок критиков и региональных предпочтений.Проект позволил получить ценные инсайты о том, какие факторы влияют на успех игры. На основе полученных данных можно более точно прогнозировать спрос и эффективно распределять бюджет на рекламу.
#
# Интернет-магазин «Стримчик» может использовать полученные данные для:
#
# * Прогнозирования спроса,
# * Выбора игр для рекламы,
# * Персонализации маркетинга по регионам.
#
# Проект выполнен в полном объеме, все шаги исследования выполнены корректно, гипотезы проверены, графики и таблицы построены. Анализ позволяет принимать обоснованные маркетинговые решения на основе исторических данных.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Итоговый вывод завершает твое исследование. Представлены основные результаты полученные в ходе анализа, но самое главное - даны рекомендации по  развитию бизнеса. Это важное качество для специалиста. Развивай его и дальше
#
#
# ---
#
# Не забудь подкорректировать вывод после исправлений
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
# ---
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями и выявляешь выбросы в числовых данных, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Пропуски
#
# 2) Неявные дубликаты
#
# 3) Зависимости
#
# 4) Смотреть на общие продажи лучше через призму медианы
#
# 5) Гипотезы провести по логам актуального периода
#
# 6) Подправить выводы, после изменений
#
# ---
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
#
# В остальном всё чудно😊
#
#
# Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊</div>
